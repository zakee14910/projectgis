# %%
from google.colab import drive
drive.mount('/content/drive')

# Define the base directory for your project
import os
base_dir = '/content/drive/MyDrive/coconut_plantation_research'

# Verify the directory structure
# !mkdir -p {base_dir}/code {base_dir}/data/raw {base_dir}/data/processed {base_dir}/results/figures {base_dir}/results/tables

print(f"Project directory: {base_dir}")
# !ls -la {base_dir}
# Out:
# Mounted at /content/drive
# Project directory: /content/drive/MyDrive/coconut_plantation_research
# total 12
# drwx------ 2 root root 4096 Apr 12 09:14 code
# drwx------ 4 root root 4096 Apr 12 09:14 data
# drwx------ 4 root root 4096 Apr 12 09:14 results

# %%
# Install required packages
# !pip install earthengine-api geemap
# !pip install rasterio

# Note: Many packages like numpy, pandas, matplotlib, scikit-learn,
# opencv-python, and tensorflow are pre-installed in Colab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 75.9 MB/s eta 0:00:00
# ...

# %%
import ee

# Authenticate and initialize Earth Engine
try:
  ee.Initialize(project='researchmsc')
  print('Earth Engine already initialized')
except:
  ee.Authenticate()
  ee.Initialize(project='researchmsc')
  print('Earth Engine initialized')
# Out:
# Earth Engine initialized

# %% [markdown]
# Test your Earth Engine setup:

# %%
# Create a simple map to test Earth Engine
import geemap

Map = geemap.Map()
Map.add_basemap('SATELLITE')

# Display the map
Map

# Save the map to HTML in your Google Drive
map_html_path = f"{base_dir}/results/test_map.html"
Map.to_html(map_html_path)
print(f"Map saved to: {map_html_path}")
# Out:
# Map saved to: /content/drive/MyDrive/coconut_plantation_research/results/test_map.html
